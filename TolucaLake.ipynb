# %%
import pandas as pd

# %%
df = pd.read_csv('https://data.lacity.org/api/views/pvft-t768/rows.csv?accessType=DOWNLOAD')
df['total'] = 1

# %%
toluca_df = df[df.NCName == 'GREATER TOLUCA LAKE NC']

# %%
toluca_df.head(2)
# Out:
#           SRNumber             CreatedDate             UpdatedDate  \
# 432   1-1418401878  08/06/2019 06:17:56 PM  08/06/2019 06:17:57 PM
# 1407  1-1418208920  08/06/2019 03:38:05 PM  08/06/2019 03:38:08 PM
#
#      ActionTaken Owner  RequestType Status RequestSource  \
# 432   SR Created   BOS  Bulky Items   Open    Mobile App
# 1407  SR Created   BOS  Bulky Items   Open    Mobile App
#
#      CreatedByUserOrganization MobileOS  ... TBMPage TBMColumn TBMRow  \
# 432               Self Service      iOS  ...   563.0         A    5.0
# 1407              Self Service  Android  ...   562.0         J    3.0
#
#                    APC   CD   CDMember    NC                  NCName  \
# 432   South Valley APC  4.0  David Ryu  28.0  GREATER TOLUCA LAKE NC
# 1407  South Valley APC  4.0  David Ryu  28.0  GREATER TOLUCA LAKE NC
#
#        PolicePrecinct total
# 432   NORTH HOLLYWOOD     1
# 1407  NORTH HOLLYWOOD     1
#
# [2 rows x 35 columns]

# %%
mobile_open_pending = toluca_df[(toluca_df.RequestSource == 'Mobile App') & (toluca_df.Status == 'Open' ) | (toluca_df.Status == 'Pending' )  ]

# %%
import folium

colors = {
    'Pending': 'blue',
    'Open': 'red'
}

m = folium.Map(location=[34.1541456,-118.3621504], zoom_start=15, zoomControl=False)


for idx, row  in mobile_open_pending.iterrows():
    tool_tip = '{}: {}'.format(row.Status, row.RequestType)
    icon = folium.Icon(color=colors[row.Status], icon='info-sign')
    info_tip = "Last Updated: {}\n".format( row.UpdatedDate)
    folium.Marker([row['Latitude'], row['Longitude']], popup=info_tip, tooltip=tool_tip, icon=icon).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
